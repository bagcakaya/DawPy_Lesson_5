# %% [markdown]
# <a href="https://colab.research.google.com/github/bagcakaya/DawPy_Lesson_5/blob/main/DawPy_Lesson_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
np.random.seed(42)
df3 = pd.DataFrame(  np.random.randn(5,4),
                   index = ['A', 'B', 'C', 'D', 'E'],
                   columns = 'W X Y Z'.split()          )
df3
# Out:
#           W         X         Y         Z
# A  0.496714 -0.138264  0.647689  1.523030
# B -0.234153 -0.234137  1.579213  0.767435
# C -0.469474  0.542560 -0.463418 -0.465730
# D  0.241962 -1.913280 -1.724918 -0.562288
# E -1.012831  0.314247 -0.908024 -1.412304

# %% [markdown]
# **RESET INDEX**

# %%
df3.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  0.496714 -0.138264  0.647689  1.523030
# 1     B -0.234153 -0.234137  1.579213  0.767435
# 2     C -0.469474  0.542560 -0.463418 -0.465730
# 3     D  0.241962 -1.913280 -1.724918 -0.562288
# 4     E -1.012831  0.314247 -0.908024 -1.412304

# %%
df3.reset_index(drop=True)
# Out:
#           W         X         Y         Z
# 0  0.496714 -0.138264  0.647689  1.523030
# 1 -0.234153 -0.234137  1.579213  0.767435
# 2 -0.469474  0.542560 -0.463418 -0.465730
# 3  0.241962 -1.913280 -1.724918 -0.562288
# 4 -1.012831  0.314247 -0.908024 -1.412304

# %%
df3
# Out:
#           W         X         Y         Z
# A  0.496714 -0.138264  0.647689  1.523030
# B -0.234153 -0.234137  1.579213  0.767435
# C -0.469474  0.542560 -0.463418 -0.465730
# D  0.241962 -1.913280 -1.724918 -0.562288
# E -1.012831  0.314247 -0.908024 -1.412304

# %%
df3.reset_index(drop=True, inplace=True) #inplace kalıcı değişiklik yapar.

# %%
df3
# Out:
#           W         X         Y         Z
# 0  0.496714 -0.138264  0.647689  1.523030
# 1 -0.234153 -0.234137  1.579213  0.767435
# 2 -0.469474  0.542560 -0.463418 -0.465730
# 3  0.241962 -1.913280 -1.724918 -0.562288
# 4 -1.012831  0.314247 -0.908024 -1.412304

# %%
new_indx = np.arange(1000,1005)
new_indx
# Out:
# array([1000, 1001, 1002, 1003, 1004])

# %%
df3["new_index"] =new_indx
df3
# Out:
#           W         X         Y         Z  new_index
# 0  0.496714 -0.138264  0.647689  1.523030       1000
# 1 -0.234153 -0.234137  1.579213  0.767435       1001
# 2 -0.469474  0.542560 -0.463418 -0.465730       1002
# 3  0.241962 -1.913280 -1.724918 -0.562288       1003
# 4 -1.012831  0.314247 -0.908024 -1.412304       1004

# %%
df3.set_index("new_index") #Seçilen indexi başta gösterir.
# Out:
#                   W         X         Y         Z
# new_index
# 1000       0.496714 -0.138264  0.647689  1.523030
# 1001      -0.234153 -0.234137  1.579213  0.767435
# 1002      -0.469474  0.542560 -0.463418 -0.465730
# 1003       0.241962 -1.913280 -1.724918 -0.562288
# 1004      -1.012831  0.314247 -0.908024 -1.412304

# %%
df3.set_index("X")
# Out:
#                   W         Y         Z  new_index
# X
# -0.138264  0.496714  0.647689  1.523030       1000
# -0.234137 -0.234153  1.579213  0.767435       1001
#  0.542560 -0.469474 -0.463418 -0.465730       1002
# -1.913280  0.241962 -1.724918 -0.562288       1003
#  0.314247 -1.012831 -0.908024 -1.412304       1004

# %%
df3.set_index("new_index", inplace=True)
df3
# Out:
#                   W         X         Y         Z
# new_index
# 1000       0.496714 -0.138264  0.647689  1.523030
# 1001      -0.234153 -0.234137  1.579213  0.767435
# 1002      -0.469474  0.542560 -0.463418 -0.465730
# 1003       0.241962 -1.913280 -1.724918 -0.562288
# 1004      -1.012831  0.314247 -0.908024 -1.412304

# %%
df3.corr()
# Out:
#           W         X         Y         Z
# W  1.000000 -0.579383  0.162034  0.743211
# X -0.579383  1.000000  0.409461 -0.011964
# Y  0.162034  0.409461  1.000000  0.764853
# Z  0.743211 -0.011964  0.764853  1.000000

# %%
new_idx = ["MX", "MY", "MZ", "MW", "MT"]

# %%
df3["col1"] = new_idx
df3
# Out:
#                   W         X         Y         Z col1
# new_index
# 1000       0.496714 -0.138264  0.647689  1.523030   MX
# 1001      -0.234153 -0.234137  1.579213  0.767435   MY
# 1002      -0.469474  0.542560 -0.463418 -0.465730   MZ
# 1003       0.241962 -1.913280 -1.724918 -0.562288   MW
# 1004      -1.012831  0.314247 -0.908024 -1.412304   MT

# %%
df3.set_index("col1", inplace=True)
df3
# Out:
#              W         X         Y         Z
# col1
# MX    0.496714 -0.138264  0.647689  1.523030
# MY   -0.234153 -0.234137  1.579213  0.767435
# MZ   -0.469474  0.542560 -0.463418 -0.465730
# MW    0.241962 -1.913280 -1.724918 -0.562288
# MT   -1.012831  0.314247 -0.908024 -1.412304

# %%
df3.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df3.columns = ['X1', 'X2', 'Y3', 'Result']
df3
# Out:
#             X1        X2        Y3    Result
# col1
# MX    0.496714 -0.138264  0.647689  1.523030
# MY   -0.234153 -0.234137  1.579213  0.767435
# MZ   -0.469474  0.542560 -0.463418 -0.465730
# MW    0.241962 -1.913280 -1.724918 -0.562288
# MT   -1.012831  0.314247 -0.908024 -1.412304

# %% [markdown]
# ***Groupby&Aggregation***

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.groupby("year").count()
# Out:
#       month  passengers
# year
# 1949     12          12
# 1950     12          12
# 1951     12          12
# 1952     12          12
# 1953     12          12
# 1954     12          12
# 1955     12          12
# 1956     12          12
# 1957     12          12
# 1958     12          12
# 1959     12          12
# 1960     12          12

# %%
flights.groupby("year").sum()
# Out:
#       passengers
# year
# 1949        1520
# 1950        1676
# 1951        2042
# 1952        2364
# 1953        2700
# 1954        2867
# 1955        3408
# 1956        3939
# 1957        4421
# 1958        4572
# 1959        5140
# 1960        5714

# %%
flights.groupby("year").max()
# Out:
#       passengers
# year
# 1949         148
# 1950         170
# 1951         199
# 1952         242
# 1953         272
# 1954         302
# 1955         364
# 1956         413
# 1957         467
# 1958         505
# 1959         559
# 1960         622

# %%
flights[flights.year == 1949]
# Out:
#     year month  passengers
# 0   1949   Jan         112
# 1   1949   Feb         118
# 2   1949   Mar         132
# 3   1949   Apr         129
# 4   1949   May         121
# 5   1949   Jun         135
# 6   1949   Jul         148
# 7   1949   Aug         148
# 8   1949   Sep         136
# 9   1949   Oct         119
# 10  1949   Nov         104
# 11  1949   Dec         118

# %%
planets = sns.load_dataset("planets")
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
planets.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
planets.describe(include="all")
# Out:
#                  method       number  ...     distance         year
# count              1035  1035.000000  ...   808.000000  1035.000000
# unique               10          NaN  ...          NaN          NaN
# top     Radial Velocity          NaN  ...          NaN          NaN
# freq                553          NaN  ...          NaN          NaN
# mean                NaN     1.785507  ...   264.069282  2009.070531
# std                 NaN     1.240976  ...   733.116493     3.972567
# min                 NaN     1.000000  ...     1.350000  1989.000000
# 25%                 NaN     1.000000  ...    32.560000  2007.000000
# 50%                 NaN     1.000000  ...    55.250000  2010.000000
# 75%                 NaN     2.000000  ...   178.500000  2012.000000
# max                 NaN     7.000000  ...  8500.000000  2014.000000
#
# [11 rows x 6 columns]

# %%
planets.std()
# Out:
# number                1.240976
# orbital_period    26014.728304
# mass                  3.818617
# distance            733.116493
# year                  3.972567
# dtype: float64

# %%
planets.isnull()
# Out:
#       method  number  orbital_period   mass  distance   year
# 0      False   False           False  False     False  False
# 1      False   False           False  False     False  False
# 2      False   False           False  False     False  False
# 3      False   False           False  False     False  False
# 4      False   False           False  False     False  False
# ...      ...     ...             ...    ...       ...    ...
# 1030   False   False           False   True     False  False
# 1031   False   False           False   True     False  False
# 1032   False   False           False   True     False  False
# 1033   False   False           False   True     False  False
# 1034   False   False           False   True     False  False
#
# [1035 rows x 6 columns]

# %%
planets.method.describe()
# Out:
# count                1035
# unique                 10
# top       Radial Velocity
# freq                  553
# Name: method, dtype: object

# %%
planets.number #Sütun ismini yazarken sonunda parantez yok
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1030    1
# 1031    1
# 1032    1
# 1033    1
# 1034    1
# Name: number, Length: 1035, dtype: int64

# %%
planets["method"].value_counts() #kaç farklı string değer varsa hepsini toplayıp gösterir.
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %%
planets["method"].unique()
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Transit Timing Variations',
#        'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#        'Pulsation Timing Variations'], dtype=object)

# %%
planets.groupby("method").sum()
# Out:
#                                number  orbital_period  ...   distance     year
# method                                                 ...
# Astrometry                          2    1.262360e+03  ...      35.75     4023
# Eclipse Timing Variations          15    4.276480e+04  ...    1261.44    18090
# Imaging                            50    1.418973e+06  ...    2166.91    76347
# Microlensing                       27    2.207500e+04  ...   41440.00    46225
# Orbital Brightness Modulation       5    2.127920e+00  ...    2360.00     6035
# Pulsar Timing                      11    3.671511e+04  ...    1200.00     9992
# Pulsation Timing Variations         1    1.170000e+03  ...       0.00     2007
# Radial Velocity                   952    4.553151e+05  ...   27348.11  1110158
# Transit                           776    8.377523e+03  ...  134242.77   798461
# Transit Timing Variations           9    2.393505e+02  ...    3313.00     8050
#
# [10 rows x 5 columns]

# %%
planets.groupby("method")[["distance"]].count()
# Out:
#                                distance
# method
# Astrometry                            2
# Eclipse Timing Variations             4
# Imaging                              32
# Microlensing                         10
# Orbital Brightness Modulation         2
# Pulsar Timing                         1
# Pulsation Timing Variations           0
# Radial Velocity                     530
# Transit                             224
# Transit Timing Variations             3

# %%
planets.groupby(["method", "year"])[["distance", "orbital_period"]].std() #method ve year sütunlarından distance ve orbital_period olanları getirir.
# Out:
#                                   distance  orbital_period
# method                    year
# Astrometry                2010         NaN             NaN
#                           2013         NaN             NaN
# Eclipse Timing Variations 2008    0.000000     1729.583187
#                           2009         NaN             NaN
#                           2010    0.000000     1902.152597
# ...                                    ...             ...
# Transit                   2014  373.175115       30.841644
# Transit Timing Variations 2011         NaN             NaN
#                           2012         NaN             NaN
#                           2013         NaN             NaN
#                           2014         NaN             NaN
#
# [69 rows x 2 columns]

# %%
planets.groupby(["method", "year"])["mass"].std()
# Out:
# method                     year
# Astrometry                 2010   NaN
#                            2013   NaN
# Eclipse Timing Variations  2008   NaN
#                            2009   NaN
#                            2010   NaN
#                                    ..
# Transit                    2014   NaN
# Transit Timing Variations  2011   NaN
#                            2012   NaN
#                            2013   NaN
#                            2014   NaN
# Name: mass, Length: 69, dtype: float64

# %%
planets.groupby("method")[["orbital_period"]].describe()
# Out:
#                               orbital_period  ...
#                                        count  ...            max
# method                                        ...
# Astrometry                               2.0  ...    1016.000000
# Eclipse Timing Variations                9.0  ...   10220.000000
# Imaging                                 12.0  ...  730000.000000
# Microlensing                             7.0  ...    5100.000000
# Orbital Brightness Modulation            3.0  ...       1.544929
# Pulsar Timing                            5.0  ...   36525.000000
# Pulsation Timing Variations              1.0  ...    1170.000000
# Radial Velocity                        553.0  ...   17337.500000
# Transit                                397.0  ...     331.600590
# Transit Timing Variations                3.0  ...     160.000000
#
# [10 rows x 8 columns]

# %%
planets.describe().T
# Out:
#                  count         mean  ...       75%       max
# number          1035.0     1.785507  ...     2.000       7.0
# orbital_period   992.0  2002.917596  ...   526.005  730000.0
# mass             513.0     2.638161  ...     3.040      25.0
# distance         808.0   264.069282  ...   178.500    8500.0
# year            1035.0  2009.070531  ...  2012.000    2014.0
#
# [5 rows x 8 columns]

# %%
planets[["method"]].T
# Out:
#                    0                1     ...     1033     1034
# method  Radial Velocity  Radial Velocity  ...  Transit  Transit
#
# [1 rows x 1035 columns]

# %%
df6 = pd.DataFrame({'groups': ['A', 'B', 'C', 'A', 'B', 'C','A', 'B', 'C'],
                   'var1': [10,23,33,22,11,99,40,20,15],
                   'var2': [100,253,333,262,111,969, 232,343,123]})
df6
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    40   232
# 7      B    20   343
# 8      C    15   123

# %%
df6.groupby("groups").mean() #groupsby'dan sonra mean, median, sum vb.yazılması gerekir.
# Out:
#         var1        var2
# groups
# A       24.0  198.000000
# B       18.0  235.666667
# C       49.0  475.000000

# %%
df6.groupby("groups").agg([np.mean])
# Out:
#        var1        var2
#        mean        mean
# groups
# A        24  198.000000
# B        18  235.666667
# C        49  475.000000

# %%
df6.groupby("groups").agg(["mean"])
# Out:
#        var1        var2
#        mean        mean
# groups
# A        24  198.000000
# B        18  235.666667
# C        49  475.000000

# %%
eval("4*3.2")
# Out:
# 12.8

# %%
def kareal(a):
  return a*a

# %%
eval("kareal(8)")
# Out:
# 64

# %%
df6.groupby("groups").agg({"var1":("mean","median", "sum"),
                           "var2": ("std", "var")})
# Out:
#        var1                    var2
#        mean median  sum         std            var
# groups
# A        24     22   72   86.185846    7428.000000
# B        18     20   54  116.967232   13681.333333
# C        49     33  147  440.513337  194052.000000

# %% [markdown]
# ***Filter Function***

# %%
df6.groupby("groups").filter(lambda x: x["var1"].mean() > 19)
# Out:
#   groups  var1  var2
# 0      A    10   100
# 2      C    33   333
# 3      A    22   262
# 5      C    99   969
# 6      A    40   232
# 8      C    15   123

# %%
df6[df6.var1 > 20]
# Out:
#   groups  var1  var2
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 5      C    99   969
# 6      A    40   232

# %%
df6.groupby("groups").filter(lambda x: x["var2"].std() > 100)
# Out:
#   groups  var1  var2
# 1      B    23   253
# 2      C    33   333
# 4      B    11   111
# 5      C    99   969
# 7      B    20   343
# 8      C    15   123

# %%
df6[["var1", "var2"]].transform(lambda x: (x-x.mean())
                                           / x.std() )
# Out:
#        var1      var2
# 0 -0.738296 -0.762940
# 1 -0.266271 -0.187601
# 2  0.096826  0.113229
# 3 -0.302581 -0.153758
# 4 -0.701987 -0.721576
# 5  2.493263  2.504835
# 6  0.350993 -0.266570
# 7 -0.375200  0.150833
# 8 -0.556748 -0.676452

# %%
df6[["var1", "var2"]].apply(lambda x: (x-x.mean())
                                           / x.std() )
# Out:
#        var1      var2
# 0 -0.738296 -0.762940
# 1 -0.266271 -0.187601
# 2  0.096826  0.113229
# 3 -0.302581 -0.153758
# 4 -0.701987 -0.721576
# 5  2.493263  2.504835
# 6  0.350993 -0.266570
# 7 -0.375200  0.150833
# 8 -0.556748 -0.676452
